# %% [markdown]
# A text cell describing goals and ways to achieve my goal:
#
# My topic is Traffic Violations in Montgomery County, Maryland. For this mini project, I would like to investigate which traffic violations are the most common and which are the least common, within this dataset. This will involve parsing the data file (CSV), through an undecided time period. The dataset extends years into the past, but for the scope of this mini project I intend to analyze only a month or year's worth of entries. I am curious whether major (drunk driving, drug posession, etc) or minor (unpaid ticket, following too close, etc) offenses are more common on the road in Montgomery County.
#
# Goals/Tasks
# • Parse a year of traffic violations, probably 2025 (or only a month if there is too much data)
# • Track the types of traffic violations for these entries
# • Create pie charts with the resulting data
#
# Data Source: https://catalog.data.gov/dataset/traffic-violations?from_hint=eyJxIjoiY2FyIiwic29ydCI6InBvcHVsYXJpdHkiLCJoYXNfZG93bmxvYWQiOiJ0cnVlIn0%3D
#
# Sarah Gaddis (spastor)
